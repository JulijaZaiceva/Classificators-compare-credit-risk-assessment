# %%
import pandas as pd

# %%
df = pd.read_csv('Person_target_predictors.csv')

# %%
df.head()
# Out:
#    PersID Creating_Date Reference_Date  Target  Predictor_1  Predictor_2  \
# 0    3500      10/04/25       10/04/24       1          4.0          3.0
# 1    3515      10/04/25       10/04/24       1         10.0          6.0
# 2    3516      10/04/25       10/04/24       0          NaN          NaN
# 3    3517      10/04/25       10/04/24       0          NaN          NaN
# 4    3584      10/04/25       10/04/24       0         12.0         19.0
#
#    Predictor_3  Predictor_4  Predictor_5  Predictor_6  ...  Predictor_70  \
# 0      1215.00     121.5000         0.00          0.0  ...           NaN
# 1      7053.69      30.2733      7375.52         96.0  ...           NaN
# 2          NaN          NaN          NaN          NaN  ...           NaN
# 3          NaN          NaN          NaN          NaN  ...           NaN
# 4     21709.58     603.0438      7356.74         22.0  ...           NaN
#
#    Predictor_71  Predictor_72  Predictor_73  Predictor_74  Predictor_75  \
# ...

# %%
df.shape
# Out:
# (305093, 83)

# %%
df['Target'].sum()
# Out:
# np.int64(44905)

# %%
print(44905/305093)
# Out:
# 0.14718462894920564

# %%
df_reduced = df.sample(n=70000, random_state=42).reset_index(drop=True)

# %%
df_reduced
# Out:
#         PersID Creating_Date Reference_Date  Target  Predictor_1  Predictor_2  \
# 0       378197      10/04/25       10/04/24       0          1.0          4.0
# 1       138159      10/04/25       10/04/24       0          2.0          5.0
# 2       476747      10/04/25       10/04/24       0          1.0          1.0
# 3       628396      10/04/25       10/04/24       1          1.0          1.0
# 4      1127866      10/04/25       10/04/24       0          1.0          0.0
# ...        ...           ...            ...     ...          ...          ...
# 69995    31797      10/04/25       10/04/24       1          8.0         12.0
# 69996    95300      10/04/25       10/04/24       0          7.0          2.0
# 69997   214219      10/04/25       10/04/24       0          3.0          6.0
# 69998   502343      10/04/25       10/04/24       0          NaN          NaN
# 69999  1113198      10/04/25       10/04/24       0          NaN          NaN
#
# ...

# %%
df_reduced.shape
# Out:
# (70000, 83)

# %%
df_reduced['Target'].sum()
# Out:
# np.int64(10300)

# %%
print(10300/70000)
# Out:
# 0.14714285714285713

# %%
df_reduced.to_csv('Data_BD_181ric090.csv')
